# %%
import geopandas as gpd

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
print(world.crs)
# Out:
# {'init': 'epsg:4326'}

# %%
world.plot()

# %%
world_proj = world.to_crs({'init':'epsg:3395'})
world_proj.plot()

# %%
world = world[world.name != 'Antarctica']
world_proj = world.to_crs({'init':'epsg:3395'})

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))

# %%
print(cities.crs)
# Out:
# {'init': 'epsg:4326'}

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
world.plot(ax = ax, color = "white", edgecolor = "black")
cities.plot(ax = ax, marker = "o", color = "red", markersize = 5)

# %%
from shapely.geometry import Polygon

pt1 = (-76,45)
pt2 = (-76,46)
pt3 = (-75,46)
pt4 = (-75,45)

my_polygon = Polygon([pt1,pt2,pt3,pt4])
my_geometries = [my_polygon]
my_attributes_data = {'id':[0],'name':['test polygon']}
my_geo_data_frame = gpd.GeoDataFrame(my_attributes_data,geometry = my_geometries)
my_geo_data_frame.crs  = {'init':'epsg:4326'}
type(my_polygon)
# Out:
# shapely.geometry.polygon.Polygon

# %%
my_geo_data_frame.plot()
my_geo_data_frame.to_file('my_shapfile.shp')
